# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Overall reviewer's comment. V.1.5.</b> <a class="tocSkip"></a>
#
# Sohini,  please check my comments, we need a little bit more details.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# Sohini, thank you for sending your project. You've done a really good job on it! You write a clear code, and plot a good graphs.
#
# <span class="text-danger">There are few things that need to be corrected in your project. They're mostly minor issues that are easy to fix. Could you check my comments?  Do not hesitate to ask your tutor for help, if you have any problems!</span>
#
#
# Waiting for the new version!
#
# </div>

# %% [markdown]
# Please find my comments below—**I kindly ask that you do not move, modify, or delete them**.
#
# You can find my comments in green, yellow or red boxes like this:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
#
# </div>
#
# You can answer me by using this:
#
# <div class="alert alert-block alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# </div>

# %% [markdown]
# ## Business prospect analysis for Zubair ride share in Chicago market

# %% [markdown]
# ## Introduction
# #### The purpose of this project is to understand how weather conditions can affect the ride share business so that Zubair ride share company can decide how to proceed with their business plan or if they have to do any changes in it. It will help them to decide on budget for the company, affect of the weather on the business. Number of employees they need to run the business.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment<s></b> <a class="tocSkip"></a>
#
# Well done, we have an introduction!
# </div>
#
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment<s></b> <a class="tocSkip"></a>
#
# Please add a title.
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.<s></b> <a class="tocSkip"></a>
#
# Thank you!
# </div>

# %%
#importing libraries
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
from scipy import stats as st

# %%
from bs4 import BeautifulSoup

# %%
## retrieve data from the website
URL = 'https://practicum-content.s3.us-west-1.amazonaws.com/data-analyst-eng/moved_chicago_weather_2017.html'
req = requests.get(URL)  # GET-request
print(req.text)
# Out:
# <html>
# <head>
#     <link rel="stylesheet" href="./styles.css">
#     <title>
#         Festival News
#     </title>
# </head>
# <body>
# <h2>Chicago Weather Records, November 2017</h2>
#        <table border="1" class="dataframe" id="weather_records">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Date and time</th>
#       <th>Temperature</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2017-11-01 00:00:00</td>
#       <td>276.150</td>
#       <td>broken clouds</td>
#     </tr>
#     <tr>
#       <td>2017-11-01 01:00:00</td>
#       <td>275.700</td>
#       <td>scattered clouds</td>
#     </tr>
#     <tr>
#       <td>2017-11-01 02:00:00</td>
#       <td>275.610</td>
#       <td>overcast clouds</td>
#     </tr>
#     <tr>
#       <td>2017-11-01 03:00:00</td>
#       <td>275.350</td>
#       <td>broken clouds</td>
#     </tr>
#     <tr>
#       <td>2017-11-01 04:00:00</td>
#       <td>275.240</td>
# ...

# %%
soup= BeautifulSoup(req.text,'lxml')

# %%
soup
# Out:
# <html>
# <head>
# <link href="./styles.css" rel="stylesheet"/>
# <title>
#         Festival News
#     </title>
# </head>
# <body>
# <h2>Chicago Weather Records, November 2017</h2>
# <table border="1" class="dataframe" id="weather_records">
# <thead>
# <tr style="text-align: right;">
# <th>Date and time</th>
# <th>Temperature</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>2017-11-01 00:00:00</td>
# <td>276.150</td>
# <td>broken clouds</td>
# </tr>
# <tr>
# <td>2017-11-01 01:00:00</td>
# <td>275.700</td>
# <td>scattered clouds</td>
# </tr>
# <tr>
# <td>2017-11-01 02:00:00</td>
# <td>275.610</td>
# <td>overcast clouds</td>
# </tr>
# <tr>
# <td>2017-11-01 03:00:00</td>
# <td>275.350</td>
# <td>broken clouds</td>
# </tr>
# <tr>
# <td>2017-11-01 04:00:00</td>
# <td>275.240</td>
# <td>broken clouds</td>
# </tr>
# <tr>
# <td>2017-11-01 05:00:00</td>
# <td>275.050</td>
# <td>overcast clouds</td>
# </tr>
# <tr>
# <td>2017-11-01 06:00:00</td>
# <td>275.140</td>
# ...

# %%
## Arranging the data so it can be visually appealing
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <link href="./styles.css" rel="stylesheet"/>
#   <title>
#    Festival News
#   </title>
#  </head>
#  <body>
#   <h2>
#    Chicago Weather Records, November 2017
#   </h2>
#   <table border="1" class="dataframe" id="weather_records">
#    <thead>
#     <tr style="text-align: right;">
#      <th>
#       Date and time
#      </th>
#      <th>
#       Temperature
#      </th>
#      <th>
#       Description
#      </th>
#     </tr>
#    </thead>
#    <tbody>
#     <tr>
#      <td>
#       2017-11-01 00:00:00
#      </td>
#      <td>
#       276.150
#      </td>
#      <td>
#       broken clouds
#      </td>
#     </tr>
#     <tr>
#      <td>
#       2017-11-01 01:00:00
#      </td>
#      <td>
#       275.700
#      </td>
#      <td>
#       scattered clouds
#      </td>
#     </tr>
#     <tr>
#      <td>
#       2017-11-01 02:00:00
#      </td>
#      <td>
#       275.610
#      </td>
#      <td>
#       overcast clouds
#      </td>
#     </tr>
#     <tr>
# ...

# %%
table = soup.find('table', attrs={"id": "weather_records"})

# %%
## parsing the data
heading_table =[]
for row in table.find_all('th'):
    heading_table.append(row.text)
content=[]
for row in table.find_all('tr'):
    if not row.find_all('th'):
        content.append([element.text for element in row.find_all('td')])
weather_records = pd.DataFrame(content, columns = heading_table)
print(weather_records)
# Out:
#            Date and time Temperature       Description
# 0    2017-11-01 00:00:00     276.150     broken clouds
# 1    2017-11-01 01:00:00     275.700  scattered clouds
# 2    2017-11-01 02:00:00     275.610   overcast clouds
# 3    2017-11-01 03:00:00     275.350     broken clouds
# 4    2017-11-01 04:00:00     275.240     broken clouds
# ..                   ...         ...               ...
# 692  2017-11-29 20:00:00     281.340        few clouds
# 693  2017-11-29 21:00:00     281.690      sky is clear
# 694  2017-11-29 22:00:00     281.070        few clouds
# 695  2017-11-29 23:00:00     280.060      sky is clear
# 696  2017-11-30 00:00:00     278.460      sky is clear
#
# [697 rows x 3 columns]

# %%
data_with_links = soup.find_all('table', attrs={"id": "weather_records"})
data_with_links
# Out:
# [<table border="1" class="dataframe" id="weather_records">
#  <thead>
#  <tr style="text-align: right;">
#  <th>Date and time</th>
#  <th>Temperature</th>
#  <th>Description</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>2017-11-01 00:00:00</td>
#  <td>276.150</td>
#  <td>broken clouds</td>
#  </tr>
#  <tr>
#  <td>2017-11-01 01:00:00</td>
#  <td>275.700</td>
#  <td>scattered clouds</td>
#  </tr>
#  <tr>
#  <td>2017-11-01 02:00:00</td>
#  <td>275.610</td>
#  <td>overcast clouds</td>
#  </tr>
#  <tr>
#  <td>2017-11-01 03:00:00</td>
#  <td>275.350</td>
#  <td>broken clouds</td>
#  </tr>
#  <tr>
#  <td>2017-11-01 04:00:00</td>
#  <td>275.240</td>
#  <td>broken clouds</td>
#  </tr>
#  <tr>
#  <td>2017-11-01 05:00:00</td>
#  <td>275.050</td>
#  <td>overcast clouds</td>
#  </tr>
#  <tr>
#  <td>2017-11-01 06:00:00</td>
#  <td>275.140</td>
#  <td>overcast clouds</td>
#  </tr>
#  <tr>
#  <td>2017-11-01 07:00:00</td>
#  <td>275.230</td>
#  <td>overcast clouds</td>
#  </tr>
#  <tr>
# ...

# %%
len(data_with_links)
# Out:
# 1

# %% [markdown]
# #### Conclusion: In the above steps we started with importing libraries needed for the analysis. Then I parsed the data from the website which had the information about Chicago weather data. I used beautiful soup as it helps with parsing html documents. Also prettify code was used so that the data looks more eye appealing. Table heading, table rows and table data was loaded so that it can be used in the project.

# %%
## reading the database
cabs = pd.read_csv('/datasets/project_sql_result_01.csv')

# %%
cabs.head()
# Out:
#                       company_name  trips_amount
# 0                        Flash Cab         19558
# 1        Taxi Affiliation Services         11422
# 2                Medallion Leasing         10367
# 3                       Yellow Cab          9888
# 4  Taxi Affiliation Service Yellow          9299

# %%
## retrieving top 10 performing cabs
cabs_top_10 = cabs.head(10)
cabs_top_10
# Out:
#                         company_name  trips_amount
# 0                          Flash Cab         19558
# 1          Taxi Affiliation Services         11422
# 2                  Medallion Leasing         10367
# 3                         Yellow Cab          9888
# 4    Taxi Affiliation Service Yellow          9299
# 5          Chicago Carriage Cab Corp          9181
# 6                       City Service          8448
# 7                           Sun Taxi          7701
# 8          Star North Management LLC          7455
# 9  Blue Ribbon Taxi Association Inc.          5953

# %%
cabs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  64 non-null     object
#  1   trips_amount  64 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
cabs.duplicated().sum()
# Out:
# 0

# %%
## looking for null values
cabs.isnull().sum()
# Out:
# company_name    0
# trips_amount    0
# dtype: int64

# %%
neighborhoods =pd.read_csv('/datasets/project_sql_result_04.csv')

# %%
neighborhoods.head()
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000

# %%
neighborhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dropoff_location_name  94 non-null     object
#  1   average_trips          94 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.6+ KB

# %%
## looking for null values
neighborhoods.isnull().sum()
# Out:
# dropoff_location_name    0
# average_trips            0
# dtype: int64

# %%
## Looking for duplicated rows
neighborhoods.duplicated().sum()
# Out:
# 0

# %%
## Finding the neighborhood with most trips
neighborhoods_top_10 = neighborhoods.head(10)
neighborhoods_top_10
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000
# 5             Lake View    2420.966667
# 6            Grant Park    2068.533333
# 7         Museum Campus    1510.000000
# 8            Gold Coast    1364.233333
# 9    Sheffield & DePaul    1259.766667

# %%
trips = pd.read_csv('/datasets/project_sql_result_07.csv')

# %%
trips.head()
# Out:
#               start_ts weather_conditions  duration_seconds
# 0  2017-11-25 16:00:00               Good            2410.0
# 1  2017-11-25 14:00:00               Good            1920.0
# 2  2017-11-25 12:00:00               Good            1543.0
# 3  2017-11-04 10:00:00               Good            2512.0
# 4  2017-11-11 07:00:00               Good            1440.0

# %%
merged_df= pd.concat([cabs, neighborhoods, trips], axis=1)
merged_df =merged_df.fillna(0)
merged_df.head(10)
# Out:
#                         company_name  trips_amount dropoff_location_name  \
# 0                          Flash Cab       19558.0                  Loop
# 1          Taxi Affiliation Services       11422.0           River North
# 2                  Medallion Leasing       10367.0         Streeterville
# 3                         Yellow Cab        9888.0             West Loop
# 4    Taxi Affiliation Service Yellow        9299.0                O'Hare
# 5          Chicago Carriage Cab Corp        9181.0             Lake View
# 6                       City Service        8448.0            Grant Park
# 7                           Sun Taxi        7701.0         Museum Campus
# 8          Star North Management LLC        7455.0            Gold Coast
# 9  Blue Ribbon Taxi Association Inc.        5953.0    Sheffield & DePaul
#
#    average_trips             start_ts weather_conditions  duration_seconds
# 0   10727.466667  2017-11-25 16:00:00               Good            2410.0
# ...

# %%
trips['start_ts'] = pd.to_datetime(trips['start_ts'])   
trips['dayofweek'] = trips['start_ts'].dt.day_name()
trips['dayofweek']
# Out:
# 0       Saturday
# 1       Saturday
# 2       Saturday
# 3       Saturday
# 4       Saturday
#           ...
# 1063    Saturday
# 1064    Saturday
# 1065    Saturday
# 1066    Saturday
# 1067    Saturday
# Name: dayofweek, Length: 1068, dtype: object

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   datetime64[ns]
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   float64
#  3   dayofweek           1068 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 33.5+ KB

# %%
## looking for null values
trips.isnull().sum()
# Out:
# start_ts              0
# weather_conditions    0
# duration_seconds      0
# dayofweek             0
# dtype: int64

# %%
trips['weather_conditions'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1063    False
# 1064    False
# 1065    False
# 1066    False
# 1067    False
# Name: weather_conditions, Length: 1068, dtype: bool

# %%
## Looking for duplicated rows
trips.duplicated().sum()
# Out:
# 197

# %%
trips.drop_duplicates(inplace= True)

# %%
trips.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Conclusion: In the above steps we started with importing libraries needed for the analysis. Then I parsed the data from the website which had the information about Chicago weather data. I used beautiful soup as it helps with parsing html documents. Also prettify code was used so that the data looks more eye appealing. Table heading, table rows and table data was loaded so that it can be used in the project.¶

# %% [markdown]
# ### Conclusion:
# ##### In all the dataframes cabs, neighborhoods and trips I looked at null, duplicated data and data types. I did found duplicated data in trips dataframes it was very low so I decided to drop it. I decided to merge the cabs, trips and neighborhood data frame so I can see the data more clearly. The Flash cab has most number of rides and it has highest number of rides that ended in Loop neighborhood at 4 pm on Nov 25. Taxi Affiliation Services	was at second place with number of rides of 11422.0	and its drop off location was River North at 2 pm on same days. The weather conditions were good for both companies. Third is Medallion Leasing	Cab company with 10367.0 number of rides and drop off location as 	Streeterville on 2017-11-25 at 12 pm. Cab companies are very busy on Nov 25 maybe because it was thanksgiving weekend so their were lot of families visiting.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment<s></b> <a class="tocSkip"></a>
#
# Good start! We have our datasets and checked them!
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment<s></b> <a class="tocSkip"></a>
#
# Please add a conclusion. Also, what should we do with duplicates and why?
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment. V.2.<s></b> <a class="tocSkip"></a>
#
# We should add more details about datasets.
# </div>

# %%
cabs_top_10.plot(kind ='bar',
                 x ='company_name', 
                 y ='trips_amount',
                 xlabel ='company name',
                 ylabel ='trips amount',
                 rot= 90)
                
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment<s></b> <a class="tocSkip"></a>
#
# Very good! Thank you for sorted values for graph. It makes it more understandble.
#
# Yes, flash cab is a best here. Perhaps, because of Flash or number of trips. :)
# </div>
#
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment<s></b> <a class="tocSkip"></a>
#
# Please add a conclusion. </div>

# %% [markdown]
# ### Conclusion:
# #### Most popular cab service company is Flash cab as it has highest amount of trips. Maybe they are very cost effective or they have tremendous cab service.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.<s></b> <a class="tocSkip"></a>
#
# Well done!
# </div>

# %%
neighborhoods_top_10.plot(kind ='bar',
                 x ='dropoff_location_name', 
                 y ='average_trips',
                 xlabel ='dropoff location name',
                 ylabel ='average trips',
                 rot= 90)
                
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment<s></b> <a class="tocSkip"></a>
#
# Well done! Good locations = more popularity!
# </div>
#
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment<s></b> <a class="tocSkip"></a>
#
# Please add a conclusion.
# </div>

# %% [markdown]
# ### Conclusion:
# ##### We can see in above bar chart that Loop is the most popular drop off location as it has the highest average trips. It means most of the people live in this neighborhood or residents in this neighborhood has less private vehicle so they use more cab services.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.<s></b> <a class="tocSkip"></a>
#
# Great!</div>

# %%
good_weather = trips[trips['weather_conditions'] == 'Good']['duration_seconds']
bad_weather = trips[trips['weather_conditions'] == 'Bad']['duration_seconds']

# %%
avg_good_weather = good_weather.mean()
avg_bad_weather = bad_weather.mean()
print(f"The average duration of good weather: {avg_good_weather}")
print(f"The average duration of bad weather: {avg_bad_weather}")
# Out:
# The average duration of good weather: 2032.253112033195
# The average duration of bad weather: 2409.2297297297296

# %% [markdown]
# #### As the average is high for bad weather it looks like based on the data Chicago neighborhood the cabs take longer time during stormy and rainy days.

# %% [markdown]
# ##### Null hypothesis (H0): The duration of rides on rainy day or any other day is same
# ##### Alternate hypothesis (H1): The duration of rides on rainy day or any other day is different.

# %%
# Testing the hypothesis between good & bad weather
t_stat, p_value = ttest_ind(good_weather, bad_weather)

alpha= 0.05

print(f"T_statistics: {t_stat}")
print(f"P_value: {p_value}")

if (p_value < alpha):
    print ("we can reject the hypothesis")
else:
    print ("we can't reject the hypothesis")
# Out:
# T_statistics: -5.427957689754561
# P_value: 7.397770692813658e-08
# we can reject the hypothesis

# %% [markdown]
# ##### Null hypothesis: The duration of rides on rainy day or non rainy day  is same. Alternate hypothesis the duration of rides on rainy day or non rainy day is different. As we are rejecting the hypothesis it means based on the analysis the weather duration between rainy day and non rainy days is different.  As p value is 7.36 so there is 700 % probability of the duration being different on both days.

# %%
trips['start_ts'] = pd.to_datetime(trips['start_ts'])   
trips['dayofweek'] = trips['start_ts'].dt.day_name()

# %%
no_rainy_sat = trips[(trips['weather_conditions'] == 'Good') & (trips['dayofweek'] == 'Saturday')]['duration_seconds']
rainy_sat = trips[(trips['weather_conditions'] =='Bad')& (trips['dayofweek'] == 'Saturday')]['duration_seconds']

# %% [markdown]
# ##### Null hypothesis (H0): The duration of rides on rainy Saturday or any other Saturday is same
# ##### Alternate hypothesis (H1): The duration of rides on rainy Saturday or any other Saturday is different.

# %%
## Testing hypothesis between rainy and non rainy saturday
t_stat, p_value = ttest_ind(no_rainy_sat, rainy_sat )

alpha= 0.05

print(f"T_statistics: {t_stat}")
print(f"P_value: {p_value}")

if (p_value < alpha):
    print ("we can reject the hypothesis")
else:
    print ("we can't reject the hypothesis")
# Out:
# T_statistics: -5.427957689754561
# P_value: 7.397770692813658e-08
# we can reject the hypothesis

# %% [markdown]
# ##### Null hypothesis: The duration of rides on rainy Saturday or any other Saturday is same. Alternate hypothesis the duration of rides on rainy Saturday or any other Saturday is different. As we are rejecting the hypothesis it means based on the analysis that the duration between rainy Saturday and other Saturday is different. As p value is 7.36 so there is 700 % probability of the duration being different on both saturdays.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment </b> <a class="tocSkip"></a>
#
# You are on the right way! Please formulate two hypotheses before testing them, change the test and add details to a conclusion.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment. V.2. </b> <a class="tocSkip"></a>
#
# It looks like the previous comment wasn't saved. Please check the brief. We need more details in our hypotheses and in the code. Please do not forget to add details to the conclusion.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment.V.2.</b> <a class="tocSkip"></a>
#
# Great, we choosed correct alpha and test.
#
# Very good that we checked results by test and thank you for the graphs. It gives us the total picture.
#
#
# We can check only saturdays, but weekend is good too.
#
# </div>

# %% [markdown]
# ## Conclusion
# ##### Conclusion: In the above project after doing analysis by parsing the data from the website which had the information about Chicago weather data by using beautiful soup.
# ##### After looking at all the dataframes cabs, neighborhoods and trips I found duplicated data in trips dataframes it was very low so I decided to drop it. The Flash cab has most number of rides and it has highest number of rides that ended in Loop neighborhood at 4 pm on Nov 25. Taxi Affiliation Services	was at second place with number of rides of 11422.0	and its drop off location was River North at 2 pm on same days. The weather conditions were good for both companies.
#
# ##### Most popular cab service company is Flash cab as it has highest amount of trips. Maybe they are very cost effective or they have tremendous cab service. We can see that Loop has the highest average trips. It means most of the people live in this neighborhood or residents in this neighborhood has less private vehicle so they use more cab services. Blue Ribbon taxi association has the lowest trips among the top 10 cab companies and Sheffild & De Paul neighborhood is the leasrt popular one as drop off location. Third is Medallion Leasing	Cab company with 10367.0 number of rides and drop off location as 	Streeterville on 2017-11-25 at 12 pm. Cab companies are very busy on Nov 25 maybe because it was thanksgiving weekend so their were lot of families visiting.
#
# ###### While testing 1 st hypothesis, H0: The duration of rides on rainy day and non rainy day  is same.  H1:the duration of rides on rainy day and non rainy day is different. As we are rejecting the hypothesis it means based on the analysis the weather duration between rainy day and non rainy days is different.  As p value is 7.36 so there is 700 % probability of the duration being different on both days.
#
# ##### While testing 2nd hypothesis, H0: The duration of rides on rainy Saturday or any other Saturday is same. H1: the duration of rides on rainy Saturday or any other Saturday is different. As we are rejecting the hypothesis it means based on the analysis that the duration between rainy Saturday and other Saturday is different. As p value is 7.36 so there is 700 % probability of the duration being different on both saturdays.
#
# ###### Based on the above analysis we can conclude that during the bad weather time taken is different than good weatheR. Usually it takes more time to travel from one location to another during bad weathers sometimes there is rain water makes the traffic really bad.So one driver who can do 2 rides in a good weather can only take care of one ride. We also find out that rainy saturday verses non rainy saturdays have different ride duration.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment </b> <a class="tocSkip"></a>
#
# Please add details about whole project.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment.V.2.</b> <a class="tocSkip"></a>
#
# Thank you!
# </div>
